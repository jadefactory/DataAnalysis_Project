# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# marketing_campaign.csv	sample_data

# %%
df = pd.read_csv('marketing_campaign.csv', sep='\t', index_col=0)
df.shape
# Out:
# (2240, 28)

# %%
df.head()
# Out:
#       Year_Birth   Education Marital_Status  ...  Z_CostContact  Z_Revenue  Response
# ID                                           ...
# 5524        1957  Graduation         Single  ...              3         11         1
# 2174        1954  Graduation         Single  ...              3         11         0
# 4141        1965  Graduation       Together  ...              3         11         0
# 6182        1984  Graduation       Together  ...              3         11         0
# 5324        1981         PhD        Married  ...              3         11         0
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2240 entries, 5524 to 9405
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year_Birth           2240 non-null   int64
#  1   Education            2240 non-null   object
#  2   Marital_Status       2240 non-null   object
#  3   Income               2216 non-null   float64
#  4   Kidhome              2240 non-null   int64
#  5   Teenhome             2240 non-null   int64
#  6   Dt_Customer          2240 non-null   object
#  7   Recency              2240 non-null   int64
#  8   MntWines             2240 non-null   int64
#  9   MntFruits            2240 non-null   int64
#  10  MntMeatProducts      2240 non-null   int64
#  11  MntFishProducts      2240 non-null   int64
#  12  MntSweetProducts     2240 non-null   int64
#  13  MntGoldProds         2240 non-null   int64
#  14  NumDealsPurchases    2240 non-null   int64
#  15  NumWebPurchases      2240 non-null   int64
#  16  NumCatalogPurchases  2240 non-null   int64
#  17  NumStorePurchases    2240 non-null   int64
#  18  NumWebVisitsMonth    2240 non-null   int64
#  19  AcceptedCmp3         2240 non-null   int64
#  20  AcceptedCmp4         2240 non-null   int64
#  21  AcceptedCmp5         2240 non-null   int64
#  22  AcceptedCmp1         2240 non-null   int64
#  23  AcceptedCmp2         2240 non-null   int64
#  24  Complain             2240 non-null   int64
#  25  Z_CostContact        2240 non-null   int64
#  26  Z_Revenue            2240 non-null   int64
#  27  Response             2240 non-null   int64
# dtypes: float64(1), int64(24), object(3)
# memory usage: 507.5+ KB

# %%
df.describe()
# Out:
#         Year_Birth         Income  ...  Z_Revenue     Response
# count  2240.000000    2216.000000  ...     2240.0  2240.000000
# mean   1968.805804   52247.251354  ...       11.0     0.149107
# std      11.984069   25173.076661  ...        0.0     0.356274
# min    1893.000000    1730.000000  ...       11.0     0.000000
# 25%    1959.000000   35303.000000  ...       11.0     0.000000
# 50%    1970.000000   51381.500000  ...       11.0     0.000000
# 75%    1977.000000   68522.000000  ...       11.0     0.000000
# max    1996.000000  666666.000000  ...       11.0     1.000000
#
# [8 rows x 25 columns]

# %%
df[df['Income'].isnull()]
# Out:
#        Year_Birth   Education  ... Z_Revenue  Response
# ID                             ...
# 1994         1983  Graduation  ...        11         0
# 5255         1986  Graduation  ...        11         0
# 7281         1959         PhD  ...        11         0
# 7244         1951  Graduation  ...        11         0
# 8557         1982  Graduation  ...        11         0
# 10629        1973    2n Cycle  ...        11         0
# 8996         1957         PhD  ...        11         0
# 9235         1957  Graduation  ...        11         0
# 5798         1973      Master  ...        11         0
# 8268         1961         PhD  ...        11         0
# 1295         1963  Graduation  ...        11         0
# 2437         1989  Graduation  ...        11         0
# 2863         1970  Graduation  ...        11         0
# 10475        1970      Master  ...        11         0
# 2902         1958  Graduation  ...        11         0
# 4345         1964    2n Cycle  ...        11         0
# 3769         1972         PhD  ...        11         0
# 7187         1969      Master  ...        11         0
# 1612         1981         PhD  ...        11         0
# 5079         1971  Graduation  ...        11         0
# 10339        1954      Master  ...        11         0
# 3117         1955  Graduation  ...        11         0
# 5250         1943      Master  ...        11         1
# 8720         1978    2n Cycle  ...        11         0
#
# [24 rows x 28 columns]

# %%
corr = df.corr()
plt.figure(figsize=(20,15))
sns.heatmap(corr, annot=True)
plt.show()

# %%
df['NumCatalogPurchases'].describe()
# Out:
# count    2240.000000
# mean        2.662054
# std         2.923101
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%         4.000000
# max        28.000000
# Name: NumCatalogPurchases, dtype: float64

# %%
df[df['Income'].isnull()]
# Out:
#        Year_Birth   Education  ... Z_Revenue  Response
# ID                             ...
# 1994         1983  Graduation  ...        11         0
# 5255         1986  Graduation  ...        11         0
# 7281         1959         PhD  ...        11         0
# 7244         1951  Graduation  ...        11         0
# 8557         1982  Graduation  ...        11         0
# 10629        1973    2n Cycle  ...        11         0
# 8996         1957         PhD  ...        11         0
# 9235         1957  Graduation  ...        11         0
# 5798         1973      Master  ...        11         0
# 8268         1961         PhD  ...        11         0
# 1295         1963  Graduation  ...        11         0
# 2437         1989  Graduation  ...        11         0
# 2863         1970  Graduation  ...        11         0
# 10475        1970      Master  ...        11         0
# 2902         1958  Graduation  ...        11         0
# 4345         1964    2n Cycle  ...        11         0
# 3769         1972         PhD  ...        11         0
# 7187         1969      Master  ...        11         0
# 1612         1981         PhD  ...        11         0
# 5079         1971  Graduation  ...        11         0
# 10339        1954      Master  ...        11         0
# 3117         1955  Graduation  ...        11         0
# 5250         1943      Master  ...        11         1
# 8720         1978    2n Cycle  ...        11         0
#
# [24 rows x 28 columns]

# %%
case_4 = round(df[df['NumCatalogPurchases'] == 0]['Income'].mean(), 1)
case_3 = round(df[(df['NumCatalogPurchases'] > 0) & (df['NumCatalogPurchases'] <= 2)]['Income'].mean(), 1)
case_2 = round(df[(df['NumCatalogPurchases'] > 2) & (df['NumCatalogPurchases'] <= 4)]['Income'].mean(), 1)
case_1 = round(df[df['NumCatalogPurchases'] > 4]['Income'].mean(), 1)

# %%
print(case_1, case_2, case_3, case_4)
# Out:
# 73663.1 65999.8 45992.9 32898.6

# %%
df.loc[(df['Income'].isnull()) & (df['NumCatalogPurchases'] == 0), 'Income'] = case_4
df.loc[(df['Income'].isnull()) & ((df['NumCatalogPurchases'] > 0) & (df['NumCatalogPurchases'] <= 2)), 'Income'] = case_3
df.loc[(df['Income'].isnull()) & ((df['NumCatalogPurchases'] > 2) & (df['NumCatalogPurchases'] <= 4)), 'Income'] = case_2
df.loc[(df['Income'].isnull()) & (df['NumCatalogPurchases'] > 4), 'Income'] = case_1

# %%
df.isnull().sum()
# Out:
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Z_CostContact          0
# Z_Revenue              0
# Response               0
# dtype: int64

# %%
df['Age'] = 2021 - df['Year_Birth']

# %%
df.head()
# Out:
#       Year_Birth   Education Marital_Status  ...  Z_Revenue  Response  Age
# ID                                           ...
# 5524        1957  Graduation         Single  ...         11         1   64
# 2174        1954  Graduation         Single  ...         11         0   67
# 4141        1965  Graduation       Together  ...         11         0   56
# 6182        1984  Graduation       Together  ...         11         0   37
# 5324        1981         PhD        Married  ...         11         0   40
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'Age'],
#       dtype='object')

# %%
df['Engagement'] = df['AcceptedCmp3'] + df['AcceptedCmp4'] + df['AcceptedCmp5'] + df['AcceptedCmp1'] + df['AcceptedCmp2'] + df['Response']

# %%
df.head()
# Out:
#       Year_Birth   Education Marital_Status  ...  Response  Age  Engagement
# ID                                           ...
# 5524        1957  Graduation         Single  ...         1   64           1
# 2174        1954  Graduation         Single  ...         0   67           0
# 4141        1965  Graduation       Together  ...         0   56           0
# 6182        1984  Graduation       Together  ...         0   37           0
# 5324        1981         PhD        Married  ...         0   40           0
#
# [5 rows x 30 columns]

# %%
df['Expenditure'] = df['MntWines'] + df['MntFruits'] + df['MntMeatProducts'] + df['MntFishProducts'] + df['MntSweetProducts'] + df['MntGoldProds']

# %%
df.head()
# Out:
#       Year_Birth   Education Marital_Status  ...  Age  Engagement  Expenditure
# ID                                           ...
# 5524        1957  Graduation         Single  ...   64           1         1617
# 2174        1954  Graduation         Single  ...   67           0           27
# 4141        1965  Graduation       Together  ...   56           0          776
# 6182        1984  Graduation       Together  ...   37           0           53
# 5324        1981         PhD        Married  ...   40           0          422
#
# [5 rows x 31 columns]

# %%
df_cluster = df[['Age', 'Income', 'Expenditure', 'Engagement']].copy()
df_cluster
# Out:
#        Age   Income  Expenditure  Engagement
# ID
# 5524    64  58138.0         1617           1
# 2174    67  46344.0           27           0
# 4141    56  71613.0          776           0
# 6182    37  26646.0           53           0
# 5324    40  58293.0          422           0
# ...    ...      ...          ...         ...
# 10870   54  61223.0         1341           0
# 4001    75  64014.0          444           1
# 7270    40  56981.0         1241           1
# 8235    65  69245.0          843           0
# 9405    67  52869.0          172           1
#
# [2240 rows x 4 columns]

# %%
df_cluster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2240 entries, 5524 to 9405
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          2240 non-null   int64
#  1   Income       2240 non-null   float64
#  2   Expenditure  2240 non-null   int64
#  3   Engagement   2240 non-null   int64
# dtypes: float64(1), int64(3)
# memory usage: 87.5 KB

# %%
df_cluster['Income'] = df_cluster['Income'].astype(int)

# %%
df_cluster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2240 entries, 5524 to 9405
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          2240 non-null   int64
#  1   Income       2240 non-null   int64
#  2   Expenditure  2240 non-null   int64
#  3   Engagement   2240 non-null   int64
# dtypes: int64(4)
# memory usage: 87.5 KB

# %%
df_cluster.head()
# Out:
#       Age  Income  Expenditure  Engagement
# ID
# 5524   64   58138         1617           1
# 2174   67   46344           27           0
# 4141   56   71613          776           0
# 6182   37   26646           53           0
# 5324   40   58293          422           0

# %%
df_cluster.describe()
# Out:
#                Age         Income  Expenditure   Engagement
# count  2240.000000    2240.000000  2240.000000  2240.000000
# mean     52.194196   52197.983036   605.798214     0.446875
# std      11.984069   25094.941258   602.249288     0.890543
# min      25.000000    1730.000000     5.000000     0.000000
# 25%      44.000000   35178.000000    68.750000     0.000000
# 50%      51.000000   51277.000000   396.000000     0.000000
# 75%      62.000000   68468.250000  1045.500000     1.000000
# max     128.000000  666666.000000  2525.000000     5.000000

# %%
df_cluster['Age'].sort_values(ascending=False)
# Out:
# ID
# 11004    128
# 1150     122
# 7829     121
# 6663      81
# 6932      80
#         ...
# 10548     26
# 5184      26
# 3661      26
# 193       25
# 9909      25
# Name: Age, Length: 2240, dtype: int64

# %%
Q1 = df_cluster['Age'].quantile(0.25)
Q3 = df_cluster['Age'].quantile(0.75)

IQR = (Q3 - Q1) * 1.5
high_limit = Q3 + IQR
low_limit = Q1 - IQR

print(low_limit, high_limit)
# Out:
# 17.0 89.0

# %%
df_cluster = df_cluster[(df_cluster['Age'] >= low_limit) & (df_cluster['Age'] <= high_limit)]
df_cluster.shape
# Out:
# (2237, 4)

# %%
df_cluster.describe()
# Out:
#                Age         Income  Expenditure   Engagement
# count  2237.000000    2237.000000  2237.000000  2237.000000
# mean     52.098346   52187.361645   605.743406     0.447027
# std      11.701917   25100.299582   601.840466     0.890964
# min      25.000000    1730.000000     5.000000     0.000000
# 25%      44.000000   35178.000000    69.000000     0.000000
# 50%      51.000000   51267.000000   396.000000     0.000000
# 75%      62.000000   68462.000000  1045.000000     1.000000
# max      81.000000  666666.000000  2525.000000     5.000000

# %%
Q1 = df_cluster['Income'].quantile(0.25)
Q3 = df_cluster['Income'].quantile(0.75)

IQR = (Q3 - Q1) * 1.5
high_limit = Q3 + IQR
low_limit = Q1 - IQR

print(low_limit, high_limit)
# Out:
# -14748.0 118388.0

# %%
df_cluster = df_cluster[df_cluster['Income'] <= high_limit]
df_cluster.shape
# Out:
# (2229, 4)

# %%
df_cluster.describe()
# Out:
#                Age         Income  Expenditure   Engagement
# count  2229.000000    2229.000000  2229.000000  2229.000000
# mean     52.111261   51579.314491   605.541050     0.448632
# std      11.707430   20669.574608   601.032228     0.892158
# min      25.000000    1730.000000     5.000000     0.000000
# 25%      44.000000   34968.000000    69.000000     0.000000
# 50%      51.000000   51141.000000   397.000000     0.000000
# 75%      62.000000   68148.000000  1044.000000     1.000000
# max      81.000000  113734.000000  2525.000000     5.000000

# %%
from sklearn.cluster import KMeans

# %%
inertia = []

for i in range(2,11):
    model = KMeans(n_clusters=i, random_state=35)
    model.fit(df_cluster)
    inertia.append(model.inertia_)

inertia
# Out:
# [265891396888.16315,
#  137041423295.65994,
#  82106956093.4347,
#  54056886623.68329,
#  40181960704.89757,
#  31434716453.756763,
#  24143512097.1762,
#  19114543267.922493,
#  15376184757.12105]

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(2,11), inertia, 'o')
plt.plot(np.arange(2,11), inertia, '-', alpha=0.8)
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette = []

for i in range(2,11):
    model = KMeans(n_clusters=i, random_state=35)
    model.fit(df_cluster)
    silhouette.append(silhouette_score(df_cluster, model.labels_))

silhouette
# Out:
# [0.6120591988493772,
#  0.549900356485611,
#  0.5343671375045697,
#  0.5365907018509207,
#  0.5221736775225535,
#  0.5108076426651016,
#  0.5160745640616368,
#  0.5196064851968487,
#  0.524734484569968]

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(2,11), silhouette, 'o')
plt.plot(np.arange(2,11), silhouette, '-', alpha=0.8)
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
model = KMeans(n_clusters=2)
model.fit(df_cluster)
# Out:
# KMeans(n_clusters=2)

# %%
df_cluster['label'] = model.labels_

# %%
df_cluster.head()
# Out:
#       Age  Income  Expenditure  Engagement  label
# ID
# 5524   64   58138         1617           1      0
# 2174   67   46344           27           0      1
# 4141   56   71613          776           0      0
# 6182   37   26646           53           0      1
# 5324   40   58293          422           0      0

# %%
df_cluster.groupby('label').mean()
# Out:
#              Age        Income  Expenditure  Engagement
# label
# 0      54.299357  69532.796143  1069.879706    0.683196
# 1      50.021053  34429.014912   161.975439    0.224561

# %%
sns.boxplot(data=df_cluster, x='label', y='Age')
plt.show()

# %%
sns.boxplot(data=df_cluster, x='label', y='Income')
plt.show()

# %%
sns.boxplot(data=df_cluster, x='label', y='Expenditure')
plt.show()

# %%
sns.boxplot(data=df_cluster, x='label', y='Engagement')
plt.show()
